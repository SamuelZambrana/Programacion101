# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# # Ejercicio 1. esEntero
#
# ## Enunciado
#
# Crea el predicado `esEntero` de modo que devuelva True si el número es entero, incluso escribiendolo como 2.0

# %% [markdown]
# ## Ayuda a la implementación
#
# Recuerda los operadores aritméticos de división, tienes la división (/), la división entera (//) y el resto (%)
