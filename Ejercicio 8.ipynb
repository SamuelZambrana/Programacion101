# %% [markdown]
# # Ejercicio 8. Calcular propina
#
# ## Enunciado
#
# Crea una función que permita calcular la propina a dar en un restaurante, con los siguientes parámetros:
# - monto de la cuenta: el total a pagar por el servicio
# - porcentaje de propina a entregar: en tanto por 100
#
# Utiliza shadowing para resolverlo (con prints) y luego hazlo retornando valores

# %% [markdown]
# ## Ayuda a la implementación
#
# Recuerda que el shadowing es usar variables con el mismo nombre en distintos ámbitos.

# %%
def tip_calculator(amount:int|float, tip_percente):
    amount = amount
    tip_percente = tip_percente
    def print_tip():
        print('propina',amount*tip_percente/100)
    def return_tip():
        return amount*tip_percente/100
    print_tip()
    propina = return_tip()
    print('lapropina',propina)   
tip_calculator(200, 60)
# Out:
# propina 120.0
# lapropina 120.0
